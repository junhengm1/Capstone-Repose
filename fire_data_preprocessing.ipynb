# %% [markdown]
# **Library import**

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
from scipy import signal
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Data reading**

# %%
# data reading
temp=pd.DataFrame();
data_train=pd.DataFrame();
label_train=pd.DataFrame();
data_test=pd.DataFrame();
label_test=pd.DataFrame();

url = 'https://github.com/zhenweiw1//capstone/raw/refs/heads/main/vic_fire_history_latest.csv'
temp = pd.read_csv(url)
data_train = pd.concat([data_train, temp], axis=0)

url = 'https://github.com/zhenweiw1//capstone/raw/refs/heads/main/vic_fire_manage_zone.csv'
temp = pd.read_csv(url)
data_train = pd.concat([data_train, temp], axis=0)

url = 'https://github.com/zhenweiw1//capstone/raw/refs/heads/main/vic_fire_bushfire_prone_area.csv'
temp = pd.read_csv(url)
data_train = pd.concat([data_train, temp], axis=0)

url = 'https://github.com/zhenweiw1//capstone/raw/refs/heads/main/Rural_Country_Fire_Service_Facilities.csv'
temp = pd.read_csv(url)
data_train = pd.concat([data_train, temp], axis=0)

url = 'https://github.com/zhenweiw1//capstone/raw/refs/heads/main/Metro_Fire_Facilities.csv'
temp = pd.read_csv(url)
data_train = pd.concat([data_train, temp], axis=0)

ch_names = list(data_train.columns[:])
# train_data = np.array(data_train[ch_names])

# %% [markdown]
# **Preprocessing**

# %%
# Data normalization
normalized_filtered_train_data = z_score_normalize(filtered_train_data)
normalized_filtered_test_data = z_score_normalize(filtered_test_data)
